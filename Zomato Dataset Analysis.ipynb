# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading dataset

# %%
data = pd.read_csv(r'data/zomato.csv')

# %% [markdown]
# # Understanding the dataset

# %%
data.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
data.shape
# Out:
# (51717, 17)

# %%
data.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Dropping Redundant columns

# %%
data.drop(['url','address','phone','menu_item','dish_liked','reviews_list','listed_in(city)'],axis=1,inplace=True)
data.head()
# Out:
#                     name online_order book_table   rate  votes      location  \
# 0                  Jalsa          Yes        Yes  4.1/5    775  Banashankari
# 1         Spice Elephant          Yes         No  4.1/5    787  Banashankari
# 2        San Churro Cafe          Yes         No  3.8/5    918  Banashankari
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88  Banashankari
# 4          Grand Village           No         No  3.8/5    166  Basavanagudi
#
#              rest_type                        cuisines  \
# 0        Casual Dining  North Indian, Mughlai, Chinese
# 1        Casual Dining     Chinese, North Indian, Thai
# 2  Cafe, Casual Dining          Cafe, Mexican, Italian
# 3          Quick Bites      South Indian, North Indian
# 4        Casual Dining        North Indian, Rajasthani
#
#   approx_cost(for two people) listed_in(type)
# 0                         800          Buffet
# 1                         800          Buffet
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         51717 non-null  object
#  1   online_order                 51717 non-null  object
#  2   book_table                   51717 non-null  object
#  3   rate                         43942 non-null  object
#  4   votes                        51717 non-null  int64
#  5   location                     51696 non-null  object
#  6   rest_type                    51490 non-null  object
#  7   cuisines                     51672 non-null  object
#  8   approx_cost(for two people)  51371 non-null  object
#  9   listed_in(type)              51717 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 3.9+ MB

# %% [markdown]
# ## Dropping Duplicates

# %%
data.drop_duplicates(inplace=True)
data.shape
# Out:
# (35011, 10)

# %% [markdown]
# ## Cleaning Rate Column

# %%
data['rate'].unique
# Out:
# <bound method Series.unique of 0         4.1/5
# 1         4.1/5
# 2         3.8/5
# 3         3.7/5
# 4         3.8/5
#           ...
# 51712    3.6 /5
# 51713       NaN
# 51714       NaN
# 51715    4.3 /5
# 51716    3.4 /5
# Name: rate, Length: 35011, dtype: object>

# %% [markdown]
# ### Removing 'NEW','-' and '/5' from rate column

# %%
def handle_rate(value):
    if value=='NEW' or value=='-':
        return np.nan
    else:
        value = str(value).split('/')
        value = value[0]
        return float(value)
    
data['rate'] = data['rate'].apply(handle_rate)
data['rate'].head()
# Out:
# 0    4.1
# 1    4.1
# 2    3.8
# 3    3.7
# 4    3.8
# Name: rate, dtype: float64

# %% [markdown]
# ### Filling Null Values in Rate Column with Mean

# %%
data['rate'].isnull().sum()
# Out:
# np.int64(5097)

# %%
data['rate'].fillna(data['rate'].mean(),inplace=True)
data['rate'].isnull().sum()
# Out:
# np.int64(0)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35011 entries, 0 to 51716
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         35011 non-null  object
#  1   online_order                 35011 non-null  object
#  2   book_table                   35011 non-null  object
#  3   rate                         35011 non-null  float64
#  4   votes                        35011 non-null  int64
#  5   location                     34997 non-null  object
#  6   rest_type                    34855 non-null  object
#  7   cuisines                     34978 non-null  object
#  8   approx_cost(for two people)  34790 non-null  object
#  9   listed_in(type)              35011 non-null  object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 2.9+ MB

# %% [markdown]
# ## Dropping Null Values from all columns

# %%
data.dropna(inplace=True)
data.head()
# Out:
#                     name online_order book_table  rate  votes      location  \
# 0                  Jalsa          Yes        Yes   4.1    775  Banashankari
# 1         Spice Elephant          Yes         No   4.1    787  Banashankari
# 2        San Churro Cafe          Yes         No   3.8    918  Banashankari
# 3  Addhuri Udupi Bhojana           No         No   3.7     88  Banashankari
# 4          Grand Village           No         No   3.8    166  Basavanagudi
#
#              rest_type                        cuisines  \
# 0        Casual Dining  North Indian, Mughlai, Chinese
# 1        Casual Dining     Chinese, North Indian, Thai
# 2  Cafe, Casual Dining          Cafe, Mexican, Italian
# 3          Quick Bites      South Indian, North Indian
# 4        Casual Dining        North Indian, Rajasthani
#
#   approx_cost(for two people) listed_in(type)
# 0                         800          Buffet
# 1                         800          Buffet
# ...

# %% [markdown]
# ## Renaming columns for usability

# %%
data.rename(columns = {'approx_cost(for two people)': 'cost2plates','listed_in(type)':'type'},inplace=True)
data.head()
# Out:
#                     name online_order book_table  rate  votes      location  \
# 0                  Jalsa          Yes        Yes   4.1    775  Banashankari
# 1         Spice Elephant          Yes         No   4.1    787  Banashankari
# 2        San Churro Cafe          Yes         No   3.8    918  Banashankari
# 3  Addhuri Udupi Bhojana           No         No   3.7     88  Banashankari
# 4          Grand Village           No         No   3.8    166  Basavanagudi
#
#              rest_type                        cuisines cost2plates    type
# 0        Casual Dining  North Indian, Mughlai, Chinese         800  Buffet
# 1        Casual Dining     Chinese, North Indian, Thai         800  Buffet
# 2  Cafe, Casual Dining          Cafe, Mexican, Italian         800  Buffet
# 3          Quick Bites      South Indian, North Indian         300  Buffet
# 4        Casual Dining        North Indian, Rajasthani         600  Buffet

# %% [markdown]
# ## Cleaning 'cost2plates' Column

# %%
data['cost2plates'].unique
# Out:
# <bound method Series.unique of 0          800
# 1          800
# 2          800
# 3          300
# 4          600
#          ...
# 51712    1,500
# 51713      600
# 51714    2,000
# 51715    2,500
# 51716    1,500
# Name: cost2plates, Length: 34636, dtype: object>

# %% [markdown]
# ### Removing ',' from 'cost2plate' column

# %%
def handle_comma(value):
    value = str(value)
    if ',' in value:
        value = value.replace(',','')
        return float(value)
    else:
        return float(value)

data['cost2plates'] = data['cost2plates'].apply(handle_comma)
data['cost2plates'].head()
# Out:
# 0    800.0
# 1    800.0
# 2    800.0
# 3    300.0
# 4    600.0
# Name: cost2plates, dtype: float64

# %%
data['cost2plates'].tail()
# Out:
# 51712    1500.0
# 51713     600.0
# 51714    2000.0
# 51715    2500.0
# 51716    1500.0
# Name: cost2plates, dtype: float64

# %% [markdown]
# ## Cleaning 'rest_type' Column

# %%
rest_types = data['rest_type'].value_counts()
rest_types
# Out:
# rest_type
# Quick Bites                   12123
# Casual Dining                  7533
# Cafe                           2578
# Delivery                       1502
# Dessert Parlor                 1491
#                               ...
# Pop Up                            1
# Quick Bites, Kiosk                1
# Mess, Quick Bites                 1
# Dessert Parlor, Food Court        1
# Sweet Shop, Dessert Parlor        1
# Name: count, Length: 93, dtype: int64

# %%
rest_types_lessthan1000 = rest_types[rest_types<1000]
rest_types_lessthan1000
# Out:
# rest_type
# Casual Dining, Bar            949
# Bakery                        736
# Beverage Shop                 487
# Bar                           473
# Food Court                    424
#                              ...
# Pop Up                          1
# Quick Bites, Kiosk              1
# Mess, Quick Bites               1
# Dessert Parlor, Food Court      1
# Sweet Shop, Dessert Parlor      1
# Name: count, Length: 87, dtype: int64

# %% [markdown]
# ### Making rest_types less 1000 frequency as others

# %%
def handle_rest_type(value):
    if value in rest_types_lessthan1000:
        return 'others'
    else:
        return value
data['rest_type'] = data['rest_type'].apply(handle_rest_type)
data['rest_type'].value_counts()
# Out:
# rest_type
# Quick Bites           12123
# others                 8193
# Casual Dining          7533
# Cafe                   2578
# Delivery               1502
# Dessert Parlor         1491
# Takeaway, Delivery     1216
# Name: count, dtype: int64

# %% [markdown]
# ## Cleaning 'location' column

# %%
locations = data['location'].value_counts()
locations
# Out:
# location
# BTM                     2484
# Whitefield              1945
# HSR                     1753
# Indiranagar             1747
# Marathahalli            1649
#                         ...
# Yelahanka                  5
# Nagarbhavi                 4
# Rajarajeshwari Nagar       2
# Jakkur                     1
# Peenya                     1
# Name: count, Length: 93, dtype: int64

# %%
locations_lessthan300 = locations[locations<300]
locations_lessthan300
# Out:
# location
# Cunningham Road                  287
# Jeevan Bhima Nagar               258
# Shanti Nagar                     258
# St. Marks Road                   242
# Bommanahalli                     180
# Vasanth Nagar                    180
# Thippasandra                     173
# Basaveshwara Nagar               173
# Shivajinagar                     167
# Commercial Street                164
# Ejipura                          157
# Koramangala 8th Block            144
# Kumaraswamy Layout               131
# Koramangala 3rd Block            129
# Wilson Garden                    128
# Majestic                         119
# Nagawara                         117
# Seshadripuram                    115
# Hennur                           106
# ITPL Main Road, Whitefield       102
# HBR Layout                       100
# Varthur Main Road, Whitefield     99
# Yeshwantpur                       95
# Race Course Road                  94
# Infantry Road                     84
# ...

# %% [markdown]
# ## Making locations less 300 frequency as others

# %%
def handle_location(value):
    if value in locations_lessthan300:
        return 'others'
    else:
        return value
data['location'] = data['location'].apply(handle_location)
data['location'].value_counts()
# Out:
# location
# others                   4838
# BTM                      2484
# Whitefield               1945
# HSR                      1753
# Indiranagar              1747
# Marathahalli             1649
# Koramangala 5th Block    1605
# JP Nagar                 1400
# Jayanagar                1242
# Electronic City          1212
# Bellandur                1120
# Bannerghatta Road        1052
# Sarjapur Road             933
# Brigade Road              687
# Koramangala 7th Block     624
# Brookefield               598
# Koramangala 6th Block     590
# Koramangala 4th Block     587
# Kalyan Nagar              584
# New BEL Road              582
# Banashankari              571
# Malleshwaram              556
# MG Road                   554
# Ulsoor                    546
# Koramangala 1st Block     539
# Frazer Town               469
# Basavanagudi              463
# Rajajinagar               462
# Church Street             446
# Banaswadi                 427
# ...

# %% [markdown]
# ## Cleaning 'cuisines' column

# %%
cuisines = data['cuisines'].value_counts()
cuisines
# Out:
# cuisines
# North Indian                                   1895
# North Indian, Chinese                          1561
# South Indian                                   1172
# Bakery, Desserts                                591
# Biryani                                         557
#                                                ...
# Salad, Juices                                     1
# Pizza, Italian, Chinese, Rolls, Biryani           1
# Burger, Juices                                    1
# North Indian, Fast Food, Biryani, Beverages       1
# North Indian, Chinese, Arabian, Momos             1
# Name: count, Length: 2704, dtype: int64

# %%
cuisines_lessthan100 = cuisines[cuisines<100]
cuisines_lessthan100
# Out:
# cuisines
# Cafe, Desserts                                 99
# Fast Food, Burger                              97
# North Indian, Street Food                      96
# North Indian, Continental                      95
# North Indian, Chinese, Continental             82
#                                                ..
# Salad, Juices                                   1
# Pizza, Italian, Chinese, Rolls, Biryani         1
# Burger, Juices                                  1
# North Indian, Fast Food, Biryani, Beverages     1
# North Indian, Chinese, Arabian, Momos           1
# Name: count, Length: 2651, dtype: int64

# %%
def handle_cuisines(value):
    if value in cuisines_lessthan100:
        return 'others'
    else:
        return value
data['cuisines'] = data['cuisines'].apply(handle_cuisines)
data['cuisines'].value_counts()
# Out:
# cuisines
# others                                              19621
# North Indian                                         1895
# North Indian, Chinese                                1561
# South Indian                                         1172
# Bakery, Desserts                                      591
# Biryani                                               557
# Fast Food                                             485
# South Indian, North Indian, Chinese                   475
# Desserts                                              447
# Cafe                                                  447
# Bakery                                                385
# Chinese                                               337
# Ice Cream, Desserts                                   304
# Mithai, Street Food                                   256
# Chinese, North Indian                                 249
# North Indian, Chinese, Biryani                        234
# ...

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## Count Plot of Various Locations

# %%
loc_vc = data['location'].value_counts()

plt.figure(figsize=(16,10))
ax = sns.countplot(data['location'], order=loc_vc.index)
x_offset = 5
# Annotation
for i, t in enumerate(loc_vc.values):
    plt.text(x= t + x_offset, y = i, s = t, fontsize=11, color='black', va='center', weight='bold')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Visualizing Restaurant having Online Order facility

# %%
plt.figure(figsize=(6,6))
ax = sns.countplot(data['online_order'], palette = 'inferno')

# Annotation
for bar in ax.patches:
    width = bar.get_width()
    ax.text(
        bar.get_x() + width / 2,
        bar.get_y() + bar.get_height() / 2,
        width,
        ha='center',
        va='center',
        color='white',
        weight='bold',
        size=8,
        rotation='horizontal'
    )
plt.show()

# %% [markdown]
# ## Visualizing Restaurant having Book Table facility

# %%
plt.figure(figsize=(6,6))
ax = sns.countplot(data['book_table'],palette='rainbow')

# Annotation
for bar in ax.patches:
    width = bar.get_width()
    ax.text(
        bar.get_x() + width / 2,
        bar.get_y() + bar.get_height() / 2,
        width,
        ha='center',
        va='center',
        color='white',
        weight='bold',
        size=8,
        rotation='horizontal'
    )
plt.show()

# %% [markdown]
# ## Visualizing Online Order vs Rating

# %%
online_mean_y = data.query("online_order=='Yes'")['rate'].mean()
online_mean_n = data.query("online_order=='No'")['rate'].mean()

# Plot
sns.catplot(
    data=data, 
    x='online_order', 
    y='rate', 
    hue='online_order', 
    kind='violin', 
    split=True, 
    height=6, 
    aspect=1
)

# Line values
plt.axhline(online_mean_y, color='red', label='online avg rating')
plt.axhline(online_mean_n, color='purple', label='other avg rating')

# Annotation
plt.text(x=0.03, y=online_mean_y, s="yes = "+str(round(online_mean_y,2)), color='red', weight='bold')
plt.text(x=0.8, y=online_mean_n, s="no = "+str(round(online_mean_n,2)), color='purple', weight='bold')

# Miscellaneous
plt.legend()
plt.show()

# %% [markdown]
# ## Visualizing Book Table vs Rating

# %%
book_table_yes = data.query("book_table=='Yes'")['rate'].mean()
book_table_no = data.query("book_table=='No'")['rate'].mean()

ax = sns.catplot(x='book_table',y='rate',data=data, hue='book_table', split='True', kind='violin', height=6, aspect=1)

# Line values
plt.axhline(book_table_yes, color='red', label='booking avg rating')
plt.axhline(book_table_no, color='purple', label='no booking avg rating')

# Annotation
plt.text(x=0.0001, y=book_table_yes, s="yes = "+str(round(book_table_yes,2)), color='red', weight='bold')
plt.text(x=0.8, y=book_table_no, s="no = "+str(round(book_table_no,2)), color='purple', weight='bold')

plt.show()

# %% [markdown]
# ## Visualizing Online Order Facility location wise

# %%
data1 = data.groupby(['location','online_order'])['name'].count()
data1.to_csv('location_online.csv')
data1 = pd.read_csv('location_online.csv')
data1 = pd.pivot_table(data1,values=None,index=['location'],columns=['online_order'],fill_value=0,aggfunc=np.sum)
data1
# Out:
#                        name
# online_order             No   Yes
# location
# BTM                     802  1682
# Banashankari            260   311
# Banaswadi               208   219
# Bannerghatta Road       399   653
# Basavanagudi            182   281
# Bellandur               437   683
# Brigade Road            293   394
# Brookefield             206   392
# Church Street           182   264
# Domlur                  187   158
# Electronic City         657   555
# Frazer Town             206   263
# HSR                     438  1315
# Indiranagar             647  1100
# JP Nagar                562   838
# Jayanagar               380   862
# Kalyan Nagar            240   344
# Kammanahalli            176   241
# Koramangala 1st Block   148   391
# Koramangala 4th Block   279   308
# Koramangala 5th Block   580  1025
# Koramangala 6th Block   211   379
# Koramangala 7th Block   190   434
# Lavelle Road            237   159
# MG Road                 297   257
# ...

# %%
ax = data1.plot(kind='bar', figsize=(15, 8), align='center')

# Annotation
for bar in ax.patches:
    height = bar.get_height()
    ax.text(
        bar.get_x() + 0.1,
        bar.get_y() + height + 100,
        height,
        ha='center',
        va='center',
        color='black',
        weight='bold',
        size=8,
        rotation='vertical'
    )
plt.show()

# %% [markdown]
# ## Visualizing Book Table Facility location wise

# %%
data2 = data.groupby(['location','book_table'])['name'].count()
data2.to_csv('location_table.csv')
data2 = pd.read_csv('location_table.csv')
data2 = pd.pivot_table(data2,values=None,index=['location'],columns=['book_table'],fill_value=0,aggfunc=np.sum)
data2
# Out:
#                        name
# book_table               No  Yes
# location
# BTM                    2358  126
# Banashankari            528   43
# Banaswadi               421    6
# Bannerghatta Road       973   79
# Basavanagudi            451   12
# Bellandur              1024   96
# Brigade Road            541  146
# Brookefield             525   73
# Church Street           279  167
# Domlur                  300   45
# Electronic City        1116   96
# Frazer Town             461    8
# HSR                    1566  187
# Indiranagar            1310  437
# JP Nagar               1148  252
# Jayanagar              1015  227
# Kalyan Nagar            466  118
# Kammanahalli            383   34
# Koramangala 1st Block   497   42
# Koramangala 4th Block   340  247
# Koramangala 5th Block  1004  601
# Koramangala 6th Block   509   81
# Koramangala 7th Block   494  130
# Lavelle Road            195  201
# MG Road                 286  268
# Malleshwaram            475   81
# ...

# %%
ax = data2.plot(kind='bar',figsize=(15,8))

# Annotation
for bar in ax.patches:
    height = bar.get_height()
    ax.text(
        bar.get_x() + 0.15,
        bar.get_y() + height + 150,
        height,
        ha='center',
        va='center',
        color='black',
        weight='bold',
        size=8,
        rotation='vertical'
    )
plt.ylim(0,5000)
plt.show()

# %% [markdown]
# ## Visualizing Types of Restaurant vs Rating

# %%
plt.figure(figsize=(12,5))
sns.boxplot(
    x='type',
    y='rate',
    data=data, 
    palette='inferno'
)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Grouping Type of Restaurant location wise

# %%
data3 = data.groupby(['location','type'])['name'].count()
data3.to_csv('location_type.csv')
data3 = pd.read_csv('location_type.csv')
data3 = pd.pivot_table(data3,values=None,index=['location'],columns=['type'],fill_value=0,aggfunc=np.sum).reset_index()
data3.columns = ['location', 'Buffet', 'Cafes', 'Delivery', 'Desserts', 'Dine-out', 'Drinks & nightlife', 'Pubs and bars']
data3['Total'] = data3[['Buffet', 'Cafes', 'Delivery', 'Desserts', 'Dine-out', 'Drinks & nightlife', 'Pubs and bars']].sum(axis=1)
data3
# Out:
#                  location  Buffet  Cafes  Delivery  Desserts  Dine-out  \
# 0                     BTM      15     46      1418       110       866
# 1            Banashankari       5     24       243        46       246
# 2               Banaswadi       0     13       157        19       233
# 3       Bannerghatta Road       8     27       510        92       404
# 4            Basavanagudi       4      8       195        45       208
# 5               Bellandur      28     34       513        70       442
# 6            Brigade Road      13     24       249        55       273
# 7             Brookefield       6     17       299        42       230
# 8           Church Street      19     44       138        21       172
# 9                  Domlur      11     12       168        24       108
# 10        Electronic City      22     24       548        71       505
# 11            Frazer Town       1     10       267        46       141
# ...

# %%
data3_perc = data3.select_dtypes('number').div(data3['Total']*0.01, axis=0)
data3.update(data3_perc)
data3.drop('Total', axis=1, inplace=True)
data3.set_index('location', inplace=True)

# %%
fig, ax = plt.subplots(figsize=(12,7))
bottom = np.zeros(len(data3))

# Create each bar with values using a loop
for i, col in enumerate(data3.columns):
    ax.barh(data3.index, data3[col], left=bottom, label=col)
    bottom+=data3[col].values

# Calculate total values for positioning the total value of stacked bar (100)
totals = data3.sum(axis=1)
x_offset = 4

# Assigning total length of the bar as label (annotation)
for i, t in enumerate(totals):
    ax.text(t + x_offset, i, round(t), va='center', weight='bold')

# Applying labels (annotation) for the middle bars
for bar in ax.patches:
    width = bar.get_width()
    if width > 3:  # Only label visible bars
        ax.text(
            bar.get_x() + width / 2,
            bar.get_y() + bar.get_height() / 2,
            round(width),
            ha='center',
            va='center',
            color='white',
            weight='bold',
            size=8
        )

# Chart control commands
plt.xlim(0,130)
ax.legend(loc='upper right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Number of Votes location wise

# %%
data4 = data[['location','votes']]
data4.drop_duplicates()
data5 = data4.groupby(['location'])['votes'].sum()
data5 = data5.to_frame()
data5 = data5.sort_values('votes',ascending=False)
data5.reset_index(inplace=True)
data5.head()
# Out:
#                 location    votes
# 0  Koramangala 5th Block  1984132
# 1            Indiranagar  1129994
# 2                 others  1016001
# 3  Koramangala 4th Block   591240
# 4          Church Street   555228

# %%
plt.figure(figsize=(15,8))
sns.barplot(x=data5.location, y=data5.votes)

y_offset = 110000
# Annotation
for i, t in enumerate(data5.votes):
    plt.text(
        x= i - 0.2, 
        y = t + y_offset, 
        s = str(round(t/1000000,2))+"M", 
        fontsize=11, 
        color='black', 
        va='center', 
        rotation='vertical'
    )

plt.ylim(0,2250000)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Visualizing Top Cuisines

# %%
data6 = data[['cuisines','votes']]
data6.drop_duplicates()
data7 = data6.groupby(['cuisines'])['votes'].sum()
data7 = data7.to_frame()
data7 = data7.sort_values('votes',ascending=False)
data7.head()
# Out:
#                           votes
# cuisines
# others                 10498501
# North Indian             439263
# North Indian, Chinese    187867
# South Indian             130350
# North Indian, Mughlai     88971

# %%
data7 = data7.iloc[1:,:]
data7.reset_index(inplace=True)
data7.head()
# Out:
#                 cuisines   votes
# 0           North Indian  439263
# 1  North Indian, Chinese  187867
# 2           South Indian  130350
# 3  North Indian, Mughlai   88971
# 4                Chinese   79450

# %%
plt.figure(figsize=(15,8))
sns.barplot(x=data7.cuisines,y=data7.votes)

y_offset = 30000
# Annotation
for i, t in enumerate(data7.votes):
    plt.text(
        x= i - 0.2, 
        y = t + y_offset, 
        s = str(round(t/1000,2))+"K", 
        fontsize=11, 
        color='black', 
        va='center', 
        rotation='vertical'
    )

plt.ylim(0,500000)
plt.xticks(rotation=90)
plt.show()
